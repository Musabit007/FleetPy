# %% [markdown]
# # This code provide the demand file for FleetPy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Calculate the Need Proportion for Medical Need Rides

# %%
# Load medic visit need data
medic_visit_need = pd.read_csv('medic_visit_need.csv')
medic_visit_need
# Out:
#       tract_number                      tract_name  Total Medical Visit  \
# 0      21001970100      Adair County, Tract 970100           116.400718
# 1      21001970200      Adair County, Tract 970200           130.701292
# 2      21001970300      Adair County, Tract 970300           216.206251
# 3      21001970401      Adair County, Tract 970401           301.566243
# 4      21001970402      Adair County, Tract 970402           245.354618
# ...            ...                             ...                  ...
# 1110   21239050106   Woodford County, Tract 050106           245.115946
# 1111   21239050107   Woodford County, Tract 050107           248.863732
# 1112   21239050200   Woodford County, Tract 050200           282.790542
# 1113   21239050300   Woodford County, Tract 050300           126.373998
# 1114   21239050400   Woodford County, Tract 050400           160.513442
#
#       Total_med_rides_need
# 0                17.591899
# 1                18.882717
# 2                37.235982
# 3                53.424656
# 4                34.877868
# ...                    ...
# 1110             39.115040
# 1111             39.954814
# 1112             41.632277
# 1113             17.301463
# 1114             24.942990
#
# [1115 rows x 4 columns]

# %%
# Create a new column for need proportion
medic_visit_need['need_proportion'] = medic_visit_need['Total_med_rides_need']/medic_visit_need['Total Medical Visit']

# %%
medic_visit_need
# Out:
#       tract_number                      tract_name  Total Medical Visit  \
# 0      21001970100      Adair County, Tract 970100           116.400718
# 1      21001970200      Adair County, Tract 970200           130.701292
# 2      21001970300      Adair County, Tract 970300           216.206251
# 3      21001970401      Adair County, Tract 970401           301.566243
# 4      21001970402      Adair County, Tract 970402           245.354618
# ...            ...                             ...                  ...
# 1110   21239050106   Woodford County, Tract 050106           245.115946
# 1111   21239050107   Woodford County, Tract 050107           248.863732
# 1112   21239050200   Woodford County, Tract 050200           282.790542
# 1113   21239050300   Woodford County, Tract 050300           126.373998
# 1114   21239050400   Woodford County, Tract 050400           160.513442
#
#       Total_med_rides_need  need_proportion
# 0                17.591899         0.151132
# 1                18.882717         0.144472
# 2                37.235982         0.172224
# 3                53.424656         0.177157
# 4                34.877868         0.142153
# ...                    ...              ...
# 1110             39.115040         0.159578
# 1111             39.954814         0.160549
# 1112             41.632277         0.147219
# 1113             17.301463         0.136907
# 1114             24.942990         0.155395
#
# [1115 rows x 5 columns]

# %%
medic_visit_need['Total Medical Visit'].sum()
# Out:
# 274623.8115576943

# %%
medic_visit_need['Total_med_rides_need'].sum()
# Out:
# 42281.514099089174

# %%
medic_visit_need['need_proportion'].max()
# Out:
# 0.20180487707224

# %%
# Save the sampled data to a new CSV file
medic_visit_need.to_csv("medic_visit_need_propotion.csv", index=False)

# %% [markdown]
# ## Load the Gravity Matrix in Long Format DataFrame

# %%
# Load the Medical visit and medical need ride data
gravity_matrix_long = pd.read_csv('gravity_matrix_long.csv')

gravity_matrix_long
# Out:
#          origin_geo_id  dest_geo_id  flow_count
# 0          21001970100  21001970100    0.000000
# 1          21001970100  21001970200    0.660443
# 2          21001970100  21001970300    0.078207
# 3          21001970100  21001970401    3.174550
# 4          21001970100  21001970402    5.640341
# ...                ...          ...         ...
# 1243219    21239050400  21239050106    0.438467
# 1243220    21239050400  21239050107    0.841023
# 1243221    21239050400  21239050200    0.042113
# 1243222    21239050400  21239050300    0.091487
# 1243223    21239050400  21239050400    0.400716
#
# [1243224 rows x 3 columns]

# %%
# Rename column appropriately
gravity_matrix_long.rename(columns={'flow_count': 'attracted_trips'}, inplace=True)

gravity_matrix_long
# Out:
#          origin_geo_id  dest_geo_id  attracted_trips
# 0          21001970100  21001970100         0.000000
# 1          21001970100  21001970200         0.660443
# 2          21001970100  21001970300         0.078207
# 3          21001970100  21001970401         3.174550
# 4          21001970100  21001970402         5.640341
# ...                ...          ...              ...
# 1243219    21239050400  21239050106         0.438467
# 1243220    21239050400  21239050107         0.841023
# 1243221    21239050400  21239050200         0.042113
# 1243222    21239050400  21239050300         0.091487
# 1243223    21239050400  21239050400         0.400716
#
# [1243224 rows x 3 columns]

# %%
# Set trips to UK healthcare destination (21067000801)
UK_destination = gravity_matrix_long[gravity_matrix_long['dest_geo_id'] == 21067000801]

UK_destination
# Out:
#          origin_geo_id  dest_geo_id  attracted_trips
# 270        21001970100  21067000801         3.283400
# 1385       21001970200  21067000801         0.782332
# 2500       21001970300  21067000801         3.873214
# 3615       21001970401  21067000801         2.667262
# 4730       21001970402  21067000801         1.725057
# ...                ...          ...              ...
# 1237919    21239050106  21067000801        65.931136
# 1239034    21239050107  21067000801        57.088081
# 1240149    21239050200  21067000801        64.944824
# 1241264    21239050300  21067000801        24.980921
# 1242379    21239050400  21067000801        33.125708
#
# [1115 rows x 3 columns]

# %% [markdown]
# ## Merge tract_name and need_proportion from medic_visit_need to UK_destination

# %%
# Merge need_proportion from medic_visit_need to UK_destination
UK_destination_merged = UK_destination.merge(
    medic_visit_need[['tract_number', 'tract_name', 'need_proportion']], 
    left_on='origin_geo_id', 
    right_on='tract_number', 
    how='left'
)

# Dropping the redundant tract_number column (since it is the same as origin_geo_id)
UK_destination_merged.drop(columns=['tract_number'], inplace=True)

# Display the first few rows of the merged dataset
UK_destination_merged
# Out:
#       origin_geo_id  dest_geo_id  attracted_trips  \
# 0       21001970100  21067000801         3.283400
# 1       21001970200  21067000801         0.782332
# 2       21001970300  21067000801         3.873214
# 3       21001970401  21067000801         2.667262
# 4       21001970402  21067000801         1.725057
# ...             ...          ...              ...
# 1110    21239050106  21067000801        65.931136
# 1111    21239050107  21067000801        57.088081
# 1112    21239050200  21067000801        64.944824
# 1113    21239050300  21067000801        24.980921
# 1114    21239050400  21067000801        33.125708
#
#                           tract_name  need_proportion
# 0         Adair County, Tract 970100         0.151132
# 1         Adair County, Tract 970200         0.144472
# 2         Adair County, Tract 970300         0.172224
# 3         Adair County, Tract 970401         0.177157
# 4         Adair County, Tract 970402         0.142153
# ...                              ...              ...
# 1110   Woodford County, Tract 050106         0.159578
# 1111   Woodford County, Tract 050107         0.160549
# 1112   Woodford County, Tract 050200         0.147219
# 1113   Woodford County, Tract 050300         0.136907
# 1114   Woodford County, Tract 050400         0.155395
#
# [1115 rows x 5 columns]

# %% [markdown]
# ### Calculate number of people needing a medical ride from each census tract to UK Healthcare

# %%
# Calculate number of people needing a medical ride from each census tract to UK Healthcare

UK_destination_merged['need_med_ride'] = UK_destination_merged['attracted_trips'] * UK_destination_merged['need_proportion']

UK_destination_merged
# Out:
#       origin_geo_id  dest_geo_id  attracted_trips  \
# 0       21001970100  21067000801         3.283400
# 1       21001970200  21067000801         0.782332
# 2       21001970300  21067000801         3.873214
# 3       21001970401  21067000801         2.667262
# 4       21001970402  21067000801         1.725057
# ...             ...          ...              ...
# 1110    21239050106  21067000801        65.931136
# 1111    21239050107  21067000801        57.088081
# 1112    21239050200  21067000801        64.944824
# 1113    21239050300  21067000801        24.980921
# 1114    21239050400  21067000801        33.125708
#
#                           tract_name  need_proportion  need_med_ride
# 0         Adair County, Tract 970100         0.151132       0.496228
# 1         Adair County, Tract 970200         0.144472       0.113025
# 2         Adair County, Tract 970300         0.172224       0.667062
# 3         Adair County, Tract 970401         0.177157       0.472525
# 4         Adair County, Tract 970402         0.142153       0.245222
# ...                              ...              ...            ...
# 1110   Woodford County, Tract 050106         0.159578      10.521139
# 1111   Woodford County, Tract 050107         0.160549       9.165432
# 1112   Woodford County, Tract 050200         0.147219       9.561143
# 1113   Woodford County, Tract 050300         0.136907       3.420058
# 1114   Woodford County, Tract 050400         0.155395       5.147570
#
# [1115 rows x 6 columns]

# %%
UK_destination_merged.describe()
# Out:
#        origin_geo_id   dest_geo_id  attracted_trips  need_proportion  \
# count   1.115000e+03  1.115000e+03      1115.000000      1109.000000
# mean    2.111067e+10  2.106700e+10         9.242970         0.153281
# std     6.156300e+07  0.000000e+00        23.852237         0.011643
# min     2.100197e+10  2.106700e+10         0.000000         0.130386
# 25%     2.106700e+10  2.106700e+10         0.138684         0.144555
# 50%     2.111101e+10  2.106700e+10         0.645565         0.151217
# 75%     2.115101e+10  2.106700e+10         4.483622         0.160019
# max     2.123905e+10  2.106700e+10       192.718024         0.201805
#
#        need_med_ride
# count   1.109000e+03
# mean    1.397711e+00
# std     3.564826e+00
# min     3.619483e-12
# 25%     2.285259e-02
# 50%     9.954607e-02
# 75%     6.861403e-01
# max     2.702967e+01

# %%
UK_destination_merged['need_proportion'].mean()
# Out:
# 0.15328051610824486

# %% [markdown]
# ## Round the need_med_ride column

# %%
import numpy as np
# Function to randomly round need med ride column
def random_round(value):
    mod = value % 1
    if np.random.rand() < mod:  # round up
        return np.ceil(value)
    else:  # round down
        return np.floor(value)

# Apply the function to the column
UK_destination_merged['rounded_need_med_ride'] = UK_destination_merged['need_med_ride'].apply(random_round)

UK_destination_merged
# Out:
#       origin_geo_id  dest_geo_id  attracted_trips  \
# 0       21001970100  21067000801         3.283400
# 1       21001970200  21067000801         0.782332
# 2       21001970300  21067000801         3.873214
# 3       21001970401  21067000801         2.667262
# 4       21001970402  21067000801         1.725057
# ...             ...          ...              ...
# 1110    21239050106  21067000801        65.931136
# 1111    21239050107  21067000801        57.088081
# 1112    21239050200  21067000801        64.944824
# 1113    21239050300  21067000801        24.980921
# 1114    21239050400  21067000801        33.125708
#
#                           tract_name  need_proportion  need_med_ride  \
# 0         Adair County, Tract 970100         0.151132       0.496228
# 1         Adair County, Tract 970200         0.144472       0.113025
# 2         Adair County, Tract 970300         0.172224       0.667062
# 3         Adair County, Tract 970401         0.177157       0.472525
# 4         Adair County, Tract 970402         0.142153       0.245222
# ...                              ...              ...            ...
# 1110   Woodford County, Tract 050106         0.159578      10.521139
# 1111   Woodford County, Tract 050107         0.160549       9.165432
# 1112   Woodford County, Tract 050200         0.147219       9.561143
# 1113   Woodford County, Tract 050300         0.136907       3.420058
# 1114   Woodford County, Tract 050400         0.155395       5.147570
#
#       rounded_need_med_ride
# 0                       0.0
# 1                       0.0
# 2                       0.0
# 3                       1.0
# 4                       1.0
# ...                     ...
# 1110                   11.0
# 1111                   10.0
# 1112                   10.0
# 1113                    3.0
# 1114                    5.0
#
# [1115 rows x 7 columns]

# %%
save_file = UK_destination_merged.to_csv('UK_destination_merged.csv', index=False)

# %%
UK_destination_merged['rounded_need_med_ride'].sum()
# Out:
# 1546.0

# %%
UK_destination_merged['attracted_trips'].sum()
# Out:
# 10305.911743841152

# %%
# Rename column appropriately
UK_destination_merged.rename(columns={'rounded_need_med_ride': 'perfect_pax'}, inplace=True)

UK_destination_merged
# Out:
#       origin_geo_id  dest_geo_id  attracted_trips  \
# 0       21001970100  21067000801         3.283400
# 1       21001970200  21067000801         0.782332
# 2       21001970300  21067000801         3.873214
# 3       21001970401  21067000801         2.667262
# 4       21001970402  21067000801         1.725057
# ...             ...          ...              ...
# 1110    21239050106  21067000801        65.931136
# 1111    21239050107  21067000801        57.088081
# 1112    21239050200  21067000801        64.944824
# 1113    21239050300  21067000801        24.980921
# 1114    21239050400  21067000801        33.125708
#
#                           tract_name  need_proportion  need_med_ride  \
# 0         Adair County, Tract 970100         0.151132       0.496228
# 1         Adair County, Tract 970200         0.144472       0.113025
# 2         Adair County, Tract 970300         0.172224       0.667062
# 3         Adair County, Tract 970401         0.177157       0.472525
# 4         Adair County, Tract 970402         0.142153       0.245222
# ...                              ...              ...            ...
# 1110   Woodford County, Tract 050106         0.159578      10.521139
# 1111   Woodford County, Tract 050107         0.160549       9.165432
# 1112   Woodford County, Tract 050200         0.147219       9.561143
# 1113   Woodford County, Tract 050300         0.136907       3.420058
# 1114   Woodford County, Tract 050400         0.155395       5.147570
#
#       perfect_pax
# 0             0.0
# 1             0.0
# 2             0.0
# 3             1.0
# 4             1.0
# ...           ...
# 1110         11.0
# 1111         10.0
# 1112         10.0
# 1113          3.0
# 1114          5.0
#
# [1115 rows x 7 columns]

# %% [markdown]
# ## Load KY Travel Time Data

# %%
# Load data
ky_travel_time = pd.read_csv('KY_travel_time_distance.csv')

ky_travel_time
# Out:
#          geoid_origin   origin_x   origin_y    geoid_dest     dest_x  \
# 0        2.123793e+10 -83.588704  37.738887  2.123793e+10 -83.588704
# 1        2.123793e+10 -83.588704  37.738887  2.103193e+10 -86.731982
# 2        2.123793e+10 -83.588704  37.738887  2.103193e+10 -86.723313
# 3        2.123793e+10 -83.588704  37.738887  2.103193e+10 -86.517884
# 4        2.123793e+10 -83.588704  37.738887  2.103193e+10 -86.848686
# ...               ...        ...        ...           ...        ...
# 1243219  2.119593e+10 -82.380711  37.517216  2.119593e+10 -82.486145
# 1243220  2.119593e+10 -82.380711  37.517216  2.119593e+10 -82.470858
# 1243221  2.119593e+10 -82.380711  37.517216  2.119593e+10 -82.562128
# 1243222  2.119593e+10 -82.380711  37.517216  2.119593e+10 -82.192534
# 1243223  2.119593e+10 -82.380711  37.517216  2.119593e+10 -82.481005
#
#             dest_y  travel_distance  travel_time
# 0        37.738887         0.000000     0.000000
# 1        37.225166       212.131433   254.830000
# 2        37.087762       218.796836   262.365000
# 3        37.236586       206.800490   245.881667
# 4        37.157033       221.002026   269.431667
# ...            ...              ...          ...
# 1243219  37.621373        23.598183    51.371667
# 1243220  37.313760        38.993935    55.928333
# 1243221  37.548172        20.724521    32.423333
# 1243222  37.562992        22.869686    42.480000
# 1243223  37.461693        19.646128    35.041667
#
# [1243224 rows x 8 columns]

# %%
# Strip spaces from column names to avoid hidden issues
ky_travel_time.columns = ky_travel_time.columns.str.strip()

# %%
# Convert geoid_origin and geoid_dest to whole numbers (integers)
ky_travel_time["geoid_origin"] = ky_travel_time["geoid_origin"].astype("int64")
ky_travel_time["geoid_dest"] = ky_travel_time["geoid_dest"].astype("int64")

# %%
ky_travel_time
# Out:
#          geoid_origin   origin_x   origin_y   geoid_dest     dest_x  \
# 0         21237930200 -83.588704  37.738887  21237930200 -83.588704
# 1         21237930200 -83.588704  37.738887  21031930300 -86.731982
# 2         21237930200 -83.588704  37.738887  21031930400 -86.723313
# 3         21237930200 -83.588704  37.738887  21031930200 -86.517884
# 4         21237930200 -83.588704  37.738887  21031930500 -86.848686
# ...               ...        ...        ...          ...        ...
# 1243219   21195931200 -82.380711  37.517216  21195930100 -82.486145
# 1243220   21195931200 -82.380711  37.517216  21195931000 -82.470858
# 1243221   21195931200 -82.380711  37.517216  21195930200 -82.562128
# 1243222   21195931200 -82.380711  37.517216  21195931600 -82.192534
# 1243223   21195931200 -82.380711  37.517216  21195930400 -82.481005
#
#             dest_y  travel_distance  travel_time
# 0        37.738887         0.000000     0.000000
# 1        37.225166       212.131433   254.830000
# 2        37.087762       218.796836   262.365000
# 3        37.236586       206.800490   245.881667
# 4        37.157033       221.002026   269.431667
# ...            ...              ...          ...
# 1243219  37.621373        23.598183    51.371667
# 1243220  37.313760        38.993935    55.928333
# 1243221  37.548172        20.724521    32.423333
# 1243222  37.562992        22.869686    42.480000
# 1243223  37.461693        19.646128    35.041667
#
# [1243224 rows x 8 columns]

# %% [markdown]
# ## Set KY travel time to UK healthcare destination (21067000801)

# %%
# Set KY travel time to UK healthcare destination (21067000801)
UK_travel_time = ky_travel_time[ky_travel_time['geoid_dest'] == 21067000801]

UK_travel_time
# Out:
#          geoid_origin   origin_x   origin_y   geoid_dest     dest_x  \
# 955       21237930200 -83.588704  37.738887  21067000801 -84.503067
# 2070      21031930300 -86.731982  37.225166  21067000801 -84.503067
# 3185      21031930400 -86.723313  37.087762  21067000801 -84.503067
# 4300      21031930200 -86.517884  37.236586  21067000801 -84.503067
# 5415      21031930500 -86.848686  37.157033  21067000801 -84.503067
# ...               ...        ...        ...          ...        ...
# 1238605   21195931000 -82.470858  37.313760  21067000801 -84.503067
# 1239720   21195930200 -82.562128  37.548172  21067000801 -84.503067
# 1240835   21195931600 -82.192534  37.562992  21067000801 -84.503067
# 1241950   21195930400 -82.481005  37.461693  21067000801 -84.503067
# 1243065   21195931200 -82.380711  37.517216  21067000801 -84.503067
#
#             dest_y  travel_distance  travel_time
# 955      38.029765        65.408739    79.028333
# 2070     38.029765       148.986106   185.936667
# 3185     38.029765       155.651509   193.491667
# 4300     38.029765       144.001703   177.725000
# 5415     38.029765       157.856637   200.431667
# ...            ...              ...          ...
# 1238605  38.029765       164.232045   202.548333
# 1239720  38.029765       139.721687   171.733333
# 1240835  38.029765       168.855804   209.820000
# 1241950  38.029765       147.997688   185.013333
# 1243065  38.029765       157.296842   198.510000
#
# [1115 rows x 8 columns]

# %% [markdown]
# ## Merge need_proportion from medic_visit_need to UK_destination

# %%
# Merge need_proportion from medic_visit_need to UK_destination
UK_demand_time = UK_destination_merged.merge(
    UK_travel_time[['geoid_origin', 'travel_time', 'travel_distance']], 
    left_on='origin_geo_id', 
    right_on='geoid_origin', 
    how='left'
)

# Dropping the redundant tract_number column (since it is the same as origin_geo_id)
UK_demand_time.drop(columns=['geoid_origin'], inplace=True)

# Display the first few rows of the merged dataset
UK_demand_time
# Out:
#       origin_geo_id  dest_geo_id  attracted_trips  \
# 0       21001970100  21067000801         3.283400
# 1       21001970200  21067000801         0.782332
# 2       21001970300  21067000801         3.873214
# 3       21001970401  21067000801         2.667262
# 4       21001970402  21067000801         1.725057
# ...             ...          ...              ...
# 1110    21239050106  21067000801        65.931136
# 1111    21239050107  21067000801        57.088081
# 1112    21239050200  21067000801        64.944824
# 1113    21239050300  21067000801        24.980921
# 1114    21239050400  21067000801        33.125708
#
#                           tract_name  need_proportion  need_med_ride  \
# 0         Adair County, Tract 970100         0.151132       0.496228
# 1         Adair County, Tract 970200         0.144472       0.113025
# 2         Adair County, Tract 970300         0.172224       0.667062
# 3         Adair County, Tract 970401         0.177157       0.472525
# 4         Adair County, Tract 970402         0.142153       0.245222
# ...                              ...              ...            ...
# 1110   Woodford County, Tract 050106         0.159578      10.521139
# 1111   Woodford County, Tract 050107         0.160549       9.165432
# 1112   Woodford County, Tract 050200         0.147219       9.561143
# 1113   Woodford County, Tract 050300         0.136907       3.420058
# 1114   Woodford County, Tract 050400         0.155395       5.147570
#
#       perfect_pax  travel_time  travel_distance
# 0             0.0   109.511667        76.315819
# 1             0.0   114.236667        96.260890
# 2             0.0   121.711667        84.799048
# 3             1.0   126.026667        98.933289
# 4             1.0   124.051667       102.547380
# ...           ...          ...              ...
# 1110         11.0    23.390000        11.451775
# 1111         10.0    24.463333        16.278102
# 1112         10.0    36.700000        20.590366
# 1113          3.0    24.755000        17.000261
# 1114          5.0    29.895000        19.649981
#
# [1115 rows x 9 columns]

# %%
## Select relevant columns

UK_demand_time_df = UK_demand_time[['origin_geo_id', 'dest_geo_id', 'perfect_pax', 'travel_time']]

UK_demand_time_df
# Out:
#       origin_geo_id  dest_geo_id  perfect_pax  travel_time
# 0       21001970100  21067000801          0.0   109.511667
# 1       21001970200  21067000801          0.0   114.236667
# 2       21001970300  21067000801          0.0   121.711667
# 3       21001970401  21067000801          1.0   126.026667
# 4       21001970402  21067000801          1.0   124.051667
# ...             ...          ...          ...          ...
# 1110    21239050106  21067000801         11.0    23.390000
# 1111    21239050107  21067000801         10.0    24.463333
# 1112    21239050200  21067000801         10.0    36.700000
# 1113    21239050300  21067000801          3.0    24.755000
# 1114    21239050400  21067000801          5.0    29.895000
#
# [1115 rows x 4 columns]

# %%
# Check rows with NaN values
nan_rows = UK_demand_time_df[UK_demand_time_df["perfect_pax"].isna()]
print(nan_rows)
# Out:
#       origin_geo_id  dest_geo_id  perfect_pax  travel_time
# 64      21015980100  21067000801          NaN    93.930000
# 124     21029980100  21067000801          NaN   128.073333
# 203     21047980100  21067000801          NaN   271.713333
# 678     21111980100  21067000801          NaN    96.973333
# 803     21143980100  21067000801          NaN   280.261667
# 1054    21221980200  21067000801          NaN   272.666667

# %%
# Store NaN values as zero and convert perfect_pax to integer

UK_demand_time_df["perfect_pax"] = pd.to_numeric(UK_demand_time_df["perfect_pax"], errors="coerce").fillna(0).astype("int64")
# Out:
# C:\Users\Musa\AppData\Local\Temp\ipykernel_15660\1209832893.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_demand_time_df["perfect_pax"] = pd.to_numeric(UK_demand_time_df["perfect_pax"], errors="coerce").fillna(0).astype("int64")

# %%
# Randomly round travel time
import numpy as np
# Function to randomly round travel time
def random_round(value):
    mod = value % 1
    if np.random.rand() < mod:  # round up
        return np.ceil(value)
    else:  # round down
        return np.floor(value)

# Apply the function to the column
UK_demand_time_df['travel time'] = UK_demand_time_df['travel_time'].apply(random_round)
# Out:
# C:\Users\Musa\AppData\Local\Temp\ipykernel_15660\1868262373.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_demand_time_df['travel time'] = UK_demand_time_df['travel_time'].apply(random_round)

# %%
# Convert geoid_origin and geoid_dest to whole numbers (integers)
UK_demand_time_df["travel time"] = UK_demand_time_df["travel time"].astype("int64")
# Out:
# C:\Users\Musa\AppData\Local\Temp\ipykernel_15660\1370371533.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_demand_time_df["travel time"] = UK_demand_time_df["travel time"].astype("int64")

# %%
# Rename
UK_demand_time_df.rename(columns={'travel_time': 't_time'}, inplace=True)
# Out:
# C:\Users\Musa\AppData\Local\Temp\ipykernel_15660\3415290718.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   UK_demand_time_df.rename(columns={'travel_time': 't_time'}, inplace=True)

# %%
UK_demand_time_df
# Out:
#       origin_geo_id  dest_geo_id  perfect_pax      t_time  travel time
# 0       21001970100  21067000801            0  109.511667          110
# 1       21001970200  21067000801            0  114.236667          115
# 2       21001970300  21067000801            0  121.711667          122
# 3       21001970401  21067000801            1  126.026667          126
# 4       21001970402  21067000801            1  124.051667          124
# ...             ...          ...          ...         ...          ...
# 1110    21239050106  21067000801           11   23.390000           23
# 1111    21239050107  21067000801           10   24.463333           24
# 1112    21239050200  21067000801           10   36.700000           36
# 1113    21239050300  21067000801            3   24.755000           25
# 1114    21239050400  21067000801            5   29.895000           30
#
# [1115 rows x 5 columns]

# %%
UK_demand_time_df['travel time'].mean()
# Out:
# 121.51748878923767

# %% [markdown]
# ## Develop the Ordinary Scheduling Approach

# %%
# Constants
HOSPITAL_OPEN_TIME = 28800  # 08:00 in seconds
HOSPITAL_CLOSE_TIME = 61200  # 17:00 in seconds
ARRIVE_EARLY_TIME = 900  # arrive to appointment 15 minutes early
APPOINTMENT_DURATION = 3600  # 1 hour (in seconds)
APPOINTMENT_INCREMENT = 900  # appointments occur in 15 minute increments

# List to store new records
expanded_data = []
request_id = 1

# Process each row in the dataset
for _, row in UK_demand_time_df.iterrows():
    origin = row["origin_geo_id"]
    destination = row["dest_geo_id"]
    perfect_pax = int(row["perfect_pax"]) # Ensure it's an integer
    travel_time = row["travel time"]
    
    for _ in range(perfect_pax):
        # Generate random appointment time within hospital hours
        appointment_time = np.random.randint(HOSPITAL_OPEN_TIME/APPOINTMENT_INCREMENT, HOSPITAL_CLOSE_TIME/APPOINTMENT_INCREMENT)
        appointment_time = appointment_time * APPOINTMENT_INCREMENT
        
        # Append go-trip
        expanded_data.append([appointment_time - (travel_time*60) - ARRIVE_EARLY_TIME, origin, destination, request_id, appointment_time])
        request_id += 1
        
        # Calculate return trip time
        return_rq_time = appointment_time + APPOINTMENT_DURATION
        
        # Append return-trip
        expanded_data.append([return_rq_time, destination, origin, request_id, appointment_time])
        request_id += 1

# Create new DataFrame
UKhealthcare_demand = pd.DataFrame(expanded_data, columns=["rq_time", "origin_geo_id", "dest_geo_id", "request_id", "appointment_time"])

# %%
UKhealthcare_demand
# Out:
#       rq_time  origin_geo_id   dest_geo_id  request_id  appointment_time
# 0     51840.0   2.100197e+10  2.106700e+10           1             60300
# 1     63900.0   2.106700e+10  2.100197e+10           2             60300
# 2     24960.0   2.100197e+10  2.106700e+10           3             33300
# 3     36900.0   2.106700e+10  2.100197e+10           4             33300
# 4     51240.0   2.100197e+10  2.106700e+10           5             60300
# ...       ...            ...           ...         ...               ...
# 3087  51300.0   2.106700e+10  2.123905e+10        3088             47700
# 3088  34200.0   2.123905e+10  2.106700e+10        3089             36900
# 3089  40500.0   2.106700e+10  2.123905e+10        3090             36900
# 3090  46800.0   2.123905e+10  2.106700e+10        3091             49500
# 3091  53100.0   2.106700e+10  2.123905e+10        3092             49500
#
# [3092 rows x 5 columns]

# %%
# Convert geoid_origin and geoid_dest to whole numbers (integers)
UKhealthcare_demand["rq_time"] = UKhealthcare_demand["rq_time"].astype("int64")
UKhealthcare_demand["origin_geo_id"] = UKhealthcare_demand["origin_geo_id"].astype("int64")
UKhealthcare_demand["dest_geo_id"] = UKhealthcare_demand["dest_geo_id"].astype("int64")

# %%
UKhealthcare_demand
# Out:
#       rq_time  origin_geo_id  dest_geo_id  request_id  appointment_time
# 0       51840    21001970401  21067000801           1             60300
# 1       63900    21067000801  21001970401           2             60300
# 2       24960    21001970402  21067000801           3             33300
# 3       36900    21067000801  21001970402           4             33300
# 4       51240    21001970500  21067000801           5             60300
# ...       ...            ...          ...         ...               ...
# 3087    51300    21067000801  21239050400        3088             47700
# 3088    34200    21239050400  21067000801        3089             36900
# 3089    40500    21067000801  21239050400        3090             36900
# 3090    46800    21239050400  21067000801        3091             49500
# 3091    53100    21067000801  21239050400        3092             49500
#
# [3092 rows x 5 columns]

# %% [markdown]
# ## Use Nearest Neighbor from QGIS to Link Node Index with the Corresponding GEOID

# %%
# Load the nearest neighbor data saved from QGIS
nodes_neighbor = pd.read_csv('Ky_nearest_neighbor.csv')

# %%
nodes_neighbor = pd.DataFrame(nodes_neighbor)
nodes_neighbor
# Out:
#        fid  STATEFP  COUNTYFP  TRACTCE        GEOID    NAME  \
# 0        1       21       237   930200  21237930200  9302.0
# 1        2       21        31   930300  21031930300  9303.0
# 2        3       21        31   930400  21031930400  9304.0
# 3        4       21        31   930200  21031930200  9302.0
# 4        5       21        31   930500  21031930500  9305.0
# ...    ...      ...       ...      ...          ...     ...
# 1110  1111       21       195   931000  21195931000  9310.0
# 1111  1112       21       195   930200  21195930200  9302.0
# 1112  1113       21       195   931600  21195931600  9316.0
# 1113  1114       21       195   930400  21195930400  9304.0
# 1114  1115       21       195   931200  21195931200  9312.0
#
#                NAMELSAD  MTFCC FUNCSTAT      ALAND  ...      osm_id  \
# 0     Census Tract 9302  G5020        S  248131879  ...   168867810
# 1     Census Tract 9303  G5020        S  194557718  ...   162492111
# 2     Census Tract 9304  G5020        S  218455330  ...   162518877
# 3     Census Tract 9302  G5020        S  248312270  ...   162503493
# 4     Census Tract 9305  G5020        S  208592384  ...   162570711
# ...                 ...    ...      ...        ...  ...         ...
# 1110  Census Tract 9310  G5020        S   70345477  ...  1293312684
# 1111  Census Tract 9302  G5020        S  129254353  ...  3239794745
# 1112  Census Tract 9316  G5020        S   68228358  ...   167784806
# 1113  Census Tract 9304  G5020        S   48576134  ...   637768897
# 1114  Census Tract 9312  G5020        S  157676919  ...   167768602
#
#       is_stop_only      pos_x      pos_y  n  distance  feature_x  feature_y  \
# 0            False -83.585382  37.744319  1         0 -83.585382  37.744319
# 1            False -86.713943  37.218780  1         0 -86.713943  37.218780
# 2            False -86.679174  37.161455  1         0 -86.679174  37.161455
# 3            False -86.431922  37.236734  1         0 -86.431922  37.236734
# 4            False -86.882836  37.156223  1         0 -86.882836  37.156223
# ...            ...        ...        ... ..       ...        ...        ...
# 1110         False -82.459456  37.361679  1         0 -82.459456  37.361679
# 1111         False -82.548504  37.510748  1         0 -82.548504  37.510748
# 1112         False -82.200458  37.552682  1         0 -82.200458  37.552682
# 1113         False -82.505627  37.442679  1         0 -82.505627  37.442679
# 1114         False -82.349496  37.497612  1         0 -82.349496  37.497612
#
#       nearest_x  nearest_y
# 0    -83.585382  37.744319
# 1    -86.713943  37.218780
# 2    -86.679174  37.161455
# 3    -86.431922  37.236734
# 4    -86.882836  37.156223
# ...         ...        ...
# 1110 -82.459456  37.361679
# 1111 -82.548504  37.510748
# 1112 -82.200458  37.552682
# 1113 -82.505627  37.442679
# 1114 -82.349496  37.497612
#
# [1115 rows x 26 columns]

# %%
# Create a node lookup
node_lookup = dict(zip(nodes_neighbor['GEOID'], nodes_neighbor['node_index']))
node_lookup
# Out:
# {21237930200: 12190,
#  21031930300: 7296,
#  21031930400: 7314,
#  21031930200: 7302,
#  21031930500: 7331,
#  21031930100: 7310,
#  21111009300: 5649,
#  21093001200: 7637,
#  21111009600: 3551,
#  21111009700: 5335,
#  21111009800: 6530,
#  21093000700: 7702,
#  21093001500: 7568,
#  21093001300: 7623,
#  21093001700: 7580,
#  21093001001: 7711,
#  21093000902: 3380,
#  21093000300: 6459,
#  21093000800: 3371,
#  21093001600: 7675,
#  21093000901: 3373,
#  21093001002: 7707,
#  21137920300: 7898,
#  21093000600: 9313,
#  21093001100: 7704,
#  21067003908: 10077,
#  21067003909: 10838,
#  21067003910: 10017,
#  21067003911: 10085,
#  21067002002: 2926,
#  21111007000: 4252,
#  21111007400: 6549,
#  21111007601: 4297,
#  21111007602: 3627,
#  21137920400: 8903,
#  21137920200: 7906,
#  21035010100: 1778,
#  21111007603: 5932,
#  21067002001: 6832,
#  21067003503: 2837,
#  21067003504: 2978,
#  21067000101: 3023,
#  21067003912: 10088,
#  21047201502: 1965,
#  21047980100: 331,
#  21047201302: 244,
#  21093000202: 6201,
#  21035010700: 140,
#  21035010400: 1924,
#  21035010200: 94,
#  21235920600: 12394,
#  21235920400: 12168,
#  21235920200: 12259,
#  21235920300: 12206,
#  21235920800: 12253,
#  21235920100: 12234,
#  21235920500: 12267,
#  21235920700: 12174,
#  21017030100: 10756,
#  21067004208: 6422,
#  21067003913: 10742,
#  21111007700: 5703,
#  21111007800: 4277,
#  21111008100: 5192,
#  21229930200: 8895,
#  21229930100: 5038,
#  21229930300: 8605,
#  21111008200: 4280,
#  21111008300: 5649,
#  21017030200: 9596,
#  21017030600: 9601,
#  21017030400: 9638,
#  21017030500: 10948,
#  21017030300: 9574,
#  21051950500: 11246,
#  21171930100: 8081,
#  21171930300: 8086,
#  21171930200: 8089,
#  21227010900: 8739,
#  21111013100: 4222,
#  21111001000: 3559,
#  21111012301: 4334,
#  21157950100: 2053,
#  21157950500: 1481,
#  21157950300: 1506,
#  21157950400: 2002,
#  21053970201: 8946,
#  21207960400: 8374,
#  21207960300: 9242,
#  21207960200: 8423,
#  21015070301: 5593,
#  21015070200: 2495,
#  21231920200: 8692,
#  21231920300: 8752,
#  21231920100: 8692,
#  21231920400: 8661,
#  21111003700: 4320,
#  21145031302: 1340,
#  21145031301: 2176,
#  21009951000: 7193,
#  21009950100: 7192,
#  21009950900: 7186,
#  21009950500: 8810,
#  21039960100: 113,
#  21053970100: 7385,
#  21179930700: 8115,
#  21179930100: 4635,
#  ...}

# %%
node_lookup[21059000100]
# Out:
# 576

# %% [markdown]
# ## Apply node lookup to UKhealthcare_demand to link GEOID to node index

# %%
# Apply node lookup to UKhealthcare_demand to link the GEOID to the node index
UKhealthcare_demand['start'] = UKhealthcare_demand['origin_geo_id'].apply(lambda x : node_lookup[x])

# %%
UKhealthcare_demand['end'] = UKhealthcare_demand['dest_geo_id'].apply(lambda x : node_lookup[x])

# %%
UKhealthcare_demand
# Out:
#       rq_time  origin_geo_id  dest_geo_id  request_id  appointment_time  \
# 0       51840    21001970401  21067000801           1             60300
# 1       63900    21067000801  21001970401           2             60300
# 2       24960    21001970402  21067000801           3             33300
# 3       36900    21067000801  21001970402           4             33300
# 4       51240    21001970500  21067000801           5             60300
# ...       ...            ...          ...         ...               ...
# 3087    51300    21067000801  21239050400        3088             47700
# 3088    34200    21239050400  21067000801        3089             36900
# 3089    40500    21067000801  21239050400        3090             36900
# 3090    46800    21239050400  21067000801        3091             49500
# 3091    53100    21067000801  21239050400        3092             49500
#
#       start   end
# 0      7118  2944
# 1      2944  7118
# 2      9262  2944
# 3      2944  9262
# 4      7065  2944
# ...     ...   ...
# 3087   2944  5084
# 3088   5084  2944
# 3089   2944  5084
# 3090   5084  2944
# 3091   2944  5084
#
# [3092 rows x 7 columns]

# %% [markdown]
# ## Select relevant columns

# %%
# Select relevant columns
UKhealthcare_demand_data = UKhealthcare_demand[['rq_time', 'start', 'end', 'request_id']]

# Display the DataFrame
UKhealthcare_demand_data
# Out:
#       rq_time  start   end  request_id
# 0       51840   7118  2944           1
# 1       63900   2944  7118           2
# 2       24960   9262  2944           3
# 3       36900   2944  9262           4
# 4       51240   7065  2944           5
# ...       ...    ...   ...         ...
# 3087    51300   2944  5084        3088
# 3088    34200   5084  2944        3089
# 3089    40500   2944  5084        3090
# 3090    46800   5084  2944        3091
# 3091    53100   2944  5084        3092
#
# [3092 rows x 4 columns]

# %%
#Save file as csv
UKhealthcare_demand_data.to_csv('UKhealthcare_demand_data.csv', index=False)

# %%
UKhealthcare_demand_data['rq_time'].min()
# Out:
# 14460

# %% [markdown]
# ## Randomly Split Demand Request by 50% and 25%

# %%
# Load the Medical visit and medical need ride data
ukhealthcare_demand = pd.read_csv('UKhealthcare_demand_data.csv')

# %%
UKhealthcare_demand_data
# Out:
#       rq_time  start   end  request_id
# 0       51840   7118  2944           1
# 1       63900   2944  7118           2
# 2       24960   9262  2944           3
# 3       36900   2944  9262           4
# 4       51240   7065  2944           5
# ...       ...    ...   ...         ...
# 3087    51300   2944  5084        3088
# 3088    34200   5084  2944        3089
# 3089    40500   2944  5084        3090
# 3090    46800   5084  2944        3091
# 3091    53100   2944  5084        3092
#
# [3092 rows x 4 columns]

# %% [markdown]
# ## 50% Data

# %%
UKhealthcare_demand_data
# Out:
#       rq_time  start   end  request_id
# 0       51840   7118  2944           1
# 1       63900   2944  7118           2
# 2       24960   9262  2944           3
# 3       36900   2944  9262           4
# 4       51240   7065  2944           5
# ...       ...    ...   ...         ...
# 3087    51300   2944  5084        3088
# 3088    34200   5084  2944        3089
# 3089    40500   2944  5084        3090
# 3090    46800   5084  2944        3091
# 3091    53100   2944  5084        3092
#
# [3092 rows x 4 columns]

# %%
# Randomly select 50% of the rows
ukhealthcare_demand_50 = UKhealthcare_demand_data.sample(frac=0.5, random_state=42)

# %%
ukhealthcare_demand_50
# Out:
#       rq_time  start    end  request_id
# 2743    39600   2944   5574        2744
# 1307    42300   2944   9988        1308
# 1602    34380   2950   2944        1603
# 2623    39600   2944  10584        2624
# 2031    38700   2944   6133        2032
# ...       ...    ...    ...         ...
# 2016    31440   3417   2944        2017
# 2420    30120  11863   2944        2421
# 2507    41400   2944   6628        2508
# 2238    40140   4078   2944        2239
# 1137    53100   2944   9947        1138
#
# [1546 rows x 4 columns]

# %%
# Save the sampled data to a new CSV file
ukhealthcare_demand_50.to_csv("ukhealthcare_demand_50.csv", index=False)

# %% [markdown]
# ## 25% Data

# %%
# Randomly select 25% of the rows
ukhealthcare_demand_25 = ukhealthcare_demand.sample(frac=0.25, random_state=42)

# %%
ukhealthcare_demand_25
# Out:
#       rq_time  start   end  request_id  earliest_pickup_time  \
# 679     36000   5442  2944          69                 36000
# 1637    63000   2944  2980        1038                 63000
# 568     33780   9849  2944         229                 33780
# 790     38100   3105  2944        1821                 38100
# 1767    57600   2944  3019        1498                 57600
# ...       ...    ...   ...         ...                   ...
# 2262    45900   2944  6465        1652                 45900
# 1552    54420   7003  2944        2099                 54420
# 123     24600  11219  2944         171                 24600
# 1536    54060   4091  2944        2277                 54060
# 220     27000   4814  2944        2903                 27000
#
#       latest_pickup_time
# 679                39600
# 1637               66600
# 568                37380
# 790                41700
# 1767               61200
# ...                  ...
# 2262               49500
# 1552               58020
# 123                28200
# 1536               57660
# 220                30600
#
# [780 rows x 6 columns]

# %%
# Save the sampled data to a new CSV file
ukhealthcare_demand_25.to_csv("ukhealthcare_demand_25.csv", index=False)

# %% [markdown]
# # Smart Demand Scheduling

# %%
# Constants
HOSPITAL_OPEN_TIME = 28800  # 08:00 in seconds
HOSPITAL_CLOSE_TIME = 61200  # 17:00 in seconds
ARRIVE_EARLY_TIME = 900  # Arrive 15 minutes early
APPOINTMENT_DURATION = 3600  # 1 hour (in seconds)
APPOINTMENT_INCREMENT = 900  # Appointments in 15-minute increments

# List to store new records
expanded_data = []
request_id = 1

# Process each row in the dataset
for _, row in UK_demand_time_df.iterrows():
    origin = row["origin_geo_id"]
    destination = row["dest_geo_id"]
    perfect_pax = int(row["perfect_pax"])
    travel_time = row["travel time"]
    
    # Generate random appointment time within hospital hours
    appointment_time = np.random.randint(HOSPITAL_OPEN_TIME // APPOINTMENT_INCREMENT, HOSPITAL_CLOSE_TIME // APPOINTMENT_INCREMENT) * APPOINTMENT_INCREMENT

    for _ in range(perfect_pax):
        # Calculate go-trip request time
        rq_time = appointment_time - (travel_time * 60) - ARRIVE_EARLY_TIME
        
        # Append go-trip
        expanded_data.append([rq_time, origin, destination, request_id, appointment_time])
        request_id += 1
        
        # Calculate return trip time
        return_rq_time = appointment_time + APPOINTMENT_DURATION
        
        # Append return-trip
        expanded_data.append([return_rq_time, destination, origin, request_id, appointment_time])
        request_id += 1

# Create new DataFrame
UKhealthcare_demand_scheduling = pd.DataFrame(expanded_data, columns=["rq_time", "origin_geo_id", "dest_geo_id", "request_id", "appointment_time"])

# %%
UKhealthcare_demand_scheduling
# Out:
#       rq_time  origin_geo_id   dest_geo_id  request_id  appointment_time
# 0     23040.0   2.100197e+10  2.106700e+10           1             31500
# 1     35100.0   2.106700e+10  2.100197e+10           2             31500
# 2     45660.0   2.100197e+10  2.106700e+10           3             54000
# 3     57600.0   2.106700e+10  2.100197e+10           4             54000
# 4     20640.0   2.100197e+10  2.106700e+10           5             29700
# ...       ...            ...           ...         ...               ...
# 3087  58500.0   2.106700e+10  2.123905e+10        3088             54900
# 3088  52200.0   2.123905e+10  2.106700e+10        3089             54900
# 3089  58500.0   2.106700e+10  2.123905e+10        3090             54900
# 3090  52200.0   2.123905e+10  2.106700e+10        3091             54900
# 3091  58500.0   2.106700e+10  2.123905e+10        3092             54900
#
# [3092 rows x 5 columns]

# %%
# Apply node lookup to UKhealthcare_demand to link the GEOID to the node index
UKhealthcare_demand_scheduling['start'] = UKhealthcare_demand_scheduling['origin_geo_id'].apply(lambda x : node_lookup[x])

# %%
# Apply node lookup to UKhealthcare_demand to link the GEOID to the node index
UKhealthcare_demand_scheduling['end'] = UKhealthcare_demand_scheduling['dest_geo_id'].apply(lambda x : node_lookup[x])

# %%
UKhealthcare_demand_scheduling
# Out:
#       rq_time  origin_geo_id   dest_geo_id  request_id  appointment_time  \
# 0     23040.0   2.100197e+10  2.106700e+10           1             31500
# 1     35100.0   2.106700e+10  2.100197e+10           2             31500
# 2     45660.0   2.100197e+10  2.106700e+10           3             54000
# 3     57600.0   2.106700e+10  2.100197e+10           4             54000
# 4     20640.0   2.100197e+10  2.106700e+10           5             29700
# ...       ...            ...           ...         ...               ...
# 3087  58500.0   2.106700e+10  2.123905e+10        3088             54900
# 3088  52200.0   2.123905e+10  2.106700e+10        3089             54900
# 3089  58500.0   2.106700e+10  2.123905e+10        3090             54900
# 3090  52200.0   2.123905e+10  2.106700e+10        3091             54900
# 3091  58500.0   2.106700e+10  2.123905e+10        3092             54900
#
#       start   end
# 0      7118  2944
# 1      2944  7118
# 2      9262  2944
# 3      2944  9262
# 4      7065  2944
# ...     ...   ...
# 3087   2944  5084
# 3088   5084  2944
# 3089   2944  5084
# 3090   5084  2944
# 3091   2944  5084
#
# [3092 rows x 7 columns]

# %%
# Select relevant columns
UKhealthcare_demand_scheduling = UKhealthcare_demand_scheduling[['rq_time', 'start', 'end', 'request_id']]

# Display the DataFrame
UKhealthcare_demand_scheduling
# Out:
#       rq_time  start   end  request_id
# 0     23040.0   7118  2944           1
# 1     35100.0   2944  7118           2
# 2     45660.0   9262  2944           3
# 3     57600.0   2944  9262           4
# 4     20640.0   7065  2944           5
# ...       ...    ...   ...         ...
# 3087  58500.0   2944  5084        3088
# 3088  52200.0   5084  2944        3089
# 3089  58500.0   2944  5084        3090
# 3090  52200.0   5084  2944        3091
# 3091  58500.0   2944  5084        3092
#
# [3092 rows x 4 columns]

# %%
# Save the sampled data to a new CSV file
UKhealthcare_demand_scheduling.to_csv("UKhealthcare_demand_scheduling.csv", index=False)

# %%
# Load the data
UKhealthcare_demand_scheduling = pd.read_csv('UKhealthcare_demand_scheduling.csv')

UKhealthcare_demand_scheduling
# Out:
#       rq_time  start   end  request_id
# 0     23040.0   7118  2944           1
# 1     35100.0   2944  7118           2
# 2     45660.0   9262  2944           3
# 3     57600.0   2944  9262           4
# 4     20640.0   7065  2944           5
# ...       ...    ...   ...         ...
# 3087  58500.0   2944  5084        3088
# 3088  52200.0   5084  2944        3089
# 3089  58500.0   2944  5084        3090
# 3090  52200.0   5084  2944        3091
# 3091  58500.0   2944  5084        3092
#
# [3092 rows x 4 columns]

# %% [markdown]
# ## Randomly Split Demand Request by 50% and 25%

# %% [markdown]
# ## 50% Data

# %%
# Randomly select 50% of the rows
ukhealthcare_demand_scheduling_50 = UKhealthcare_demand_scheduling.sample(frac=0.5, random_state=42)

ukhealthcare_demand_scheduling_50
# Out:
#       rq_time  start    end  request_id
# 2743  45000.0   2944   5574        2744
# 1307  60300.0   2944   9988        1308
# 1602  58680.0   2950   2944        1603
# 2623  54000.0   2944  10584        2624
# 2031  55800.0   2944   6133        2032
# ...       ...    ...    ...         ...
# 2016  51240.0   3417   2944        2017
# 2420  28320.0  11863   2944        2421
# 2507  37800.0   2944   6628        2508
# 2238  38340.0   4078   2944        2239
# 1137  56700.0   2944   9947        1138
#
# [1546 rows x 4 columns]

# %%
# Save the sampled data to a new CSV file
ukhealthcare_demand_scheduling_50.to_csv("ukhealthcare_demand_scheduling_50.csv", index=False)

# %% [markdown]
# ## 25% Data

# %%
# Randomly select 25% of the rows
ukhealthcare_demand_scheduling_25 = UKhealthcare_demand_scheduling.sample(frac=0.25, random_state=42)

ukhealthcare_demand_scheduling_25
# Out:
#       rq_time  start    end  request_id  earliest_pickup_time  \
# 1241    54900   2944  10742        1242                 54900
# 203     62100   2944   9874         204                 62100
# 1260    49380  10742   2944        1261                 49380
# 1626    32580   6465   2944        1627                 32580
# 1578    49740   2950   2944        1579                 49740
# ...       ...    ...    ...         ...                   ...
# 2932    21360   8663   2944        2933                 21360
# 2410    56520  11902   2944        2411                 56520
# 2337    48600   2944  11758        2338                 48600
# 962     35340   2998   2944         963                 35340
# 1766    57720   6323   2944        1767                 57720
#
#       latest_pickup_time
# 1241               58500
# 203                65700
# 1260               52980
# 1626               36180
# 1578               53340
# ...                  ...
# 2932               24960
# 2410               60120
# 2337               52200
# 962                38940
# 1766               61320
#
# [766 rows x 6 columns]

# %%
# Save the sampled data to a new CSV file
ukhealthcare_demand_scheduling_25.to_csv("ukhealthcare_demand_scheduling_25.csv", index=False)
